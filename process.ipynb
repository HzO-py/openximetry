# %% [markdown]
# std-mean ###########################################################################

# %%
from spo2 import Traverse
Traverse()
# Out:
# /home/lzqhzo/spo2/openoximetry-repository-1.1.1/srcs/spo2.py:31: RuntimeWarning: Mean of empty slice
#   spo2_avg = np.nanmean(spo2, axis=1)
# /home/lzqhzo/spo2/openoximetry-repository-1.1.1/srcs/spo2.py:57: RuntimeWarning: invalid value encountered in double_scalars
#   r_val = (ac_r / dc_r) / (ac_i / dc_i)
# /home/lzqhzo/spo2/openoximetry-repository-1.1.1/srcs/spo2.py:57: RuntimeWarning: divide by zero encountered in double_scalars
#   r_val = (ac_r / dc_r) / (ac_i / dc_i)

# %% [markdown]
# min-max 5s ##########################################################################################################################

# %%
from spo2 import Traverse
Traverse()
# Out:
# /home/lzqhzo/spo2/srcs/spo2.py:112: RuntimeWarning: Mean of empty slice
#   spo2_avg = np.nanmean(spo2, axis=1)
# Lag: 11.0000
# Pearson correlation coefficient (PCC): 0.7862
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 from spo2 import Traverse
# ----> 2 Traverse()
#
# File ~/spo2/srcs/spo2.py:281, in Traverse()
#     277 if len(X[mask])<=max_lag:
#     278     # print(f"len(X[mask])<=")
#     279     continue
# --> 281 lag, pcc = get_best_pcc_with_lag(-X, y,max_lag)
#     282 # pcc, p_value = pearsonr(X[mask], y[mask])
#     283 if pcc<0.9:
#
# File ~/spo2/srcs/spo2.py:223, in get_best_pcc_with_lag(X, y, max_lag)
#     221 if not mask2:
#     222     continue
# --> 223 r, _ = pearsonr(X_shifted, y_shifted)
#     224 if abs(r) > abs(best_pcc):
#     225     best_pcc = r
#
# ...
